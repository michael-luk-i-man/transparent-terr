# %%
# import 

import pandas as pd, scipy as sp, numpy as np, seaborn as sb, requests as req, re, wikipedia as wik, urllib as url
from bs4 import BeautifulSoup as beaut

# %%
# helper function for quick printing 

def p(string):
    
        """
        Shortens the time to call print.

        Parameters
        ----------
        string: The item to print.

        Returns
        -------
        Prints the string to IO, no return.

        Raises
        ------
        Err when non-convertable.
        """
        
        print(str(string))
        
def pb():
    
        """
        Shortens the time to call print break.

        Parameters
        ----------
        string: The item to print.

        Returns
        -------
        Prints a line break.

        Raises
        ------
        Err when non-convertable.
        """
        
        print('\n')def p(string):
    
        """
        Shortens the time to call print.

        Parameters
        ----------
        string: The item to print.

        Returns
        -------
        Prints the string to IO, no return.

        Raises
        ------
        Err when non-convertable.
        """
        
        print(str(string))

# %%
# table_year_vs_numbers

year_vs_numbers = """<table class="wikitable sortable collapsible collapsed" style="text-align:right">
<caption>Terrorist Attacks in the United States<sup class="reference" id="cite_ref-globalterrorismdb_0616dist_3-0"><a href="#cite_note-globalterrorismdb_0616dist-3">[3]</a></sup><sup class="reference" id="cite_ref-gtd1993_0616dist_4-0"><a href="#cite_note-gtd1993_0616dist-4">[4]</a></sup>
</caption>
<tr style="background:#ececec; vertical-align:top;">
<th> Year </th>
<th> Number of<br/>incidents </th>
<th> Deaths </th>
<th> Injuries
</th></tr>
<tr>
<td align="center">2016</td>
<td>61</td>
<td>68</td>
<td>139
</td></tr>
<tr>
<td align="center">2015</td>
<td>38</td>
<td>44</td>
<td>52
</td></tr>
<tr>
<td align="center">2014</td>
<td>26</td>
<td>19</td>
<td>6
</td></tr>
<tr>
<td align="center">2013</td>
<td>19</td>
<td>22</td>
<td>422
</td></tr>
<tr>
<td align="center">2012</td>
<td>18</td>
<td>33</td>
<td>6
</td></tr>
<tr>
<td align="center">2011</td>
<td>10</td>
<td>0</td>
<td>2
</td></tr>
<tr>
<td align="center">2010</td>
<td>17</td>
<td>4</td>
<td>17
</td></tr>
<tr>
<td align="center">2009</td>
<td>10</td>
<td>18</td>
<td>41
</td></tr>
<tr>
<td align="center">2008</td>
<td>18</td>
<td>2</td>
<td>13
</td></tr>
<tr>
<td align="center">2007</td>
<td>9</td>
<td>0</td>
<td>0
</td></tr>
<tr>
<td align="center">2006</td>
<td>6</td>
<td>1</td>
<td>14
</td></tr>
<tr>
<td align="center">2005</td>
<td>20</td>
<td>0</td>
<td>0
</td></tr>
<tr>
<td align="center">2004</td>
<td>9</td>
<td>0</td>
<td>0
</td></tr>
<tr>
<td align="center">2003</td>
<td>32</td>
<td>0</td>
<td>0
</td></tr>
<tr>
<td align="center">2002</td>
<td>33</td>
<td>4</td>
<td>4
</td></tr>
<tr>
<td align="center">2001</td>
<td>41</td>
<td>3,003</td>
<td>6,000+
</td></tr>
<tr>
<td align="center">2000</td>
<td>32</td>
<td>0</td>
<td>7
</td></tr>
<tr>
<td align="center">1999</td>
<td>53</td>
<td>20</td>
<td>40
    """
    Loads the page and extracts HTML for future use.

    Parameters
    ----------
    string: The item to print.

    Returns
    -------
    Prints the string to IO, no return.

    Raises
    ------
    Err when non-convertable.
    """ 
    
    global soup
    soup = beaut(page, 'html.parser')

# %%
initialize_page(year_vs_numbers)

# %%
years = soup.find_all('td', {'align':'center'}) # years
years_list = []
for year in years:
#     p(year)
    if year.contents[0].isdigit():
        year = int(year.contents[0])
        years_list.append(year)
    else:
        years_list.append(year.contents[0])
    
print(years_list)
# Out:
# [2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 'Total']

# %%
year_stats = soup.find_all('td', {'align':None})
counter = 0
s_list = []
for stat in year_stats:
#     p(stat)
    stat_ = str(stat.contents[0].replace(',', ''))
    stat_ = stat_.replace('\n', '')
    stat_ = stat_.replace('+','')
    p(stat_)
    s_list.append(int(stat_)) # Post on Stackoverflow about better ways to do this.

# %%
p(s_list)
# Out:
# [61, 68, 139, 38, 44, 52, 26, 19, 6, 19, 22, 422, 18, 33, 6, 10, 0, 2, 17, 4, 17, 10, 18, 41, 18, 2, 13, 9, 0, 0, 6, 1, 14, 20, 0, 0, 9, 0, 0, 32, 0, 0, 33, 4, 4, 41, 3003, 6000, 32, 0, 7, 53, 20, 40, 30, 4, 3, 40, 2, 18, 35, 2, 119, 60, 170, 734, 56, 10, 16, 37, 10, 1005, 32, 2, 3, 30, 2, 4, 32, 5, 7, 42, 3, 14, 27, 1, 1, 34, 1, 1, 49, 1, 36, 40, 3, 13, 63, 3, 780, 44, 8, 5, 78, 11, 37, 73, 8, 15, 67, 15, 22, 69, 18, 58, 87, 8, 8, 130, 4, 17, 105, 4, 41, 149, 24, 158, 94, 16, 54, 58, 45, 33, 4, 10, 35, 247, 20, 55, 468, 33, 160, 2728, 3662, 10099]

# %%
# Condenser - three items per year
triples = []
counter_year = -1
counter_stats = -1
for year in years_list:
    current_triple = []
    for i in range(0,3): # Why? SO
        counter_stats += 1 
        current_triple.append(s_list[counter_stats])
    triples.append(current_triple)
    
p(years_list)
p(triples)

incid = 
x = 

for triple in triples:
# Out:
# [2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 'Total']
# [[61, 68, 139], [38, 44, 52], [26, 19, 6], [19, 22, 422], [18, 33, 6], [10, 0, 2], [17, 4, 17], [10, 18, 41], [18, 2, 13], [9, 0, 0], [6, 1, 14], [20, 0, 0], [9, 0, 0], [32, 0, 0], [33, 4, 4], [41, 3003, 6000], [32, 0, 7], [53, 20, 40], [30, 4, 3], [40, 2, 18], [35, 2, 119], [60, 170, 734], [56, 10, 16], [37, 10, 1005], [32, 2, 3], [30, 2, 4], [32, 5, 7], [42, 3, 14], [27, 1, 1], [34, 1, 1], [49, 1, 36], [40, 3, 13], [63, 3, 780], [44, 8, 5], [78, 11, 37], [73, 8, 15], [67, 15, 22], [69, 18, 58], [87, 8, 8], [130, 4, 17], [105, 4, 41], [149, 24, 158], [94, 16, 54], [58, 45, 33], [4, 10, 35], [247, 20, 55], [468, 33, 160], [2728, 3662, 10099]]
